# %%
import requests
from bs4 import BeautifulSoup

# %%
html = requests.get('https://www.tripadvisor.com/Hotels-g294230-Yogyakarta_Region_Java-Hotels.html')
html.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(html.content,'lxml')

# %%
hotel = []
for name in soup.findAll('div',{'class': "listing_title"}):
  hotel.append(name.text.strip())

hotel
# Out:
# ['Grand Kangen Hotel Urip Sumoharjo',
#  'Eastparc Hotel Yogyakarta',
#  'The Alana Hotel & Conference Center Malioboro Yogyakarta by ASTON',
#  'Jambuluwuk Malioboro Yogyakarta Hotel',
#  'Artotel Yogyakarta',
#  'Grand Tjokro Yogyakarta',
#  'Indies Heritage Hotel',
#  'The Rich Jogja Hotel',
#  'El Hotel Royale Yogyakarta Malioboro',
#  '@HOM Premiere Timoho',
#  'LYNN Hotel By Horison',
#  'Adhisthana Hotel Yogyakarta',
#  'Tjokro Style Yogyakarta',
#  'Zest Hotel Yogyakarta',
#  'Core Hotel Yogyakarta',
#  'Grand Sarila Yogyakarta',
#  'POP! Hotel Timoho',
#  'Horaios Malioboro Hotel',
#  'Sahid Raya Hotel & Convention Yogyakarta',
#  'Emersia Malioboro Hotel',
#  'Satoria Hotel Yogyakarta',
#  'KJ Hotel Yogyakarta',
#  'Greenhost Boutique Hotel',
#  'Swiss-Belboutique Yogyakarta',
#  'Yellow Star Gejayan Hotel',
#  'Aveon Hotel Yogyakarta by Daphna International',
#  'Grand Serela Hotel Yogyakarta',
#  'Indoluxe Rent Apartment',
#  'Hotel Citradream Yogyakarta',
#  'Ayaartta Hotel Malioboro']

# %%
ratings = []
for rating in soup.findAll('a', {'class':'ui_bubble_rating'}):
  ratings.append(rating['alt'])

ratings
# Out:
# ['4.5 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '4 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '4 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '3.5 of 5 bubbles',
#  '3.5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '4 of 5 bubbles',
#  '3.5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4.5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '3.5 of 5 bubbles',
#  '4 of 5 bubbles',
#  '3 of 5 bubbles',
#  '4 of 5 bubbles',
#  '4 of 5 bubbles']

# %%
reviews = []
for review in soup.findAll('a', {'class':'review_count'}):
  reviews.append(review.text.strip())

reviews
# Out:
# ['458 reviews',
#  '1,488 reviews',
#  '920 reviews',
#  '1,456 reviews',
#  '538 reviews',
#  '1,159 reviews',
#  '280 reviews',
#  '626 reviews',
#  '87 reviews',
#  '29 reviews',
#  '180 reviews',
#  '423 reviews',
#  '845 reviews',
#  '299 reviews',
#  '65 reviews',
#  '30 reviews',
#  '101 reviews',
#  '11 reviews',
#  '92 reviews',
#  '114 reviews',
#  '902 reviews',
#  '209 reviews',
#  '664 reviews',
#  '1,290 reviews',
#  '64 reviews',
#  '6 reviews',
#  '100 reviews',
#  '4 reviews',
#  '136 reviews',
#  '79 reviews']

# %%
harga = []
for h in soup.findAll('div',{'class': 'price-wrap'}):
  harga.append(h.text.replace('IDR','').strip())

harga[:5]
# Out:
# ['231,405\xa0134,561',
#  '785,124',
#  '384,366',
#  '390,266\xa0302,290',
#  '356,095\xa0312,188']

# %%
len(harga)
# Out:
# 30

# %%
d1 = {'Hotel':hotel,'Ratings':ratings,'No_of_reviews':reviews,'Harga':harga}

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(d1)
df
# Out:
#                                                 Hotel           Ratings  \
# 0                   Grand Kangen Hotel Urip Sumoharjo  4.5 of 5 bubbles
# 1                           Eastparc Hotel Yogyakarta  4.5 of 5 bubbles
# 2   The Alana Hotel & Conference Center Malioboro ...  4.5 of 5 bubbles
# 3               Jambuluwuk Malioboro Yogyakarta Hotel    4 of 5 bubbles
# 4                                  Artotel Yogyakarta  4.5 of 5 bubbles
# 5                             Grand Tjokro Yogyakarta  4.5 of 5 bubbles
# 6                               Indies Heritage Hotel    4 of 5 bubbles
# 7                                The Rich Jogja Hotel    4 of 5 bubbles
# 8                El Hotel Royale Yogyakarta Malioboro  4.5 of 5 bubbles
# 9                                @HOM Premiere Timoho  4.5 of 5 bubbles
# 10                              LYNN Hotel By Horison    4 of 5 bubbles
# 11                        Adhisthana Hotel Yogyakarta    4 of 5 bubbles
# 12                            Tjokro Style Yogyakarta  4.5 of 5 bubbles
# 13                              Zest Hotel Yogyakarta    4 of 5 bubbles
# 14                              Core Hotel Yogyakarta  3.5 of 5 bubbles
# 15                            Grand Sarila Yogyakarta  3.5 of 5 bubbles
# 16                                  POP! Hotel Timoho    4 of 5 bubbles
# 17                            Horaios Malioboro Hotel    4 of 5 bubbles
# 18           Sahid Raya Hotel & Convention Yogyakarta  3.5 of 5 bubbles
# 19                            Emersia Malioboro Hotel    4 of 5 bubbles
# 20                           Satoria Hotel Yogyakarta  4.5 of 5 bubbles
# 21                                KJ Hotel Yogyakarta  4.5 of 5 bubbles
# 22                           Greenhost Boutique Hotel    4 of 5 bubbles
# 23                       Swiss-Belboutique Yogyakarta    5 of 5 bubbles
# 24                          Yellow Star Gejayan Hotel    4 of 5 bubbles
# 25     Aveon Hotel Yogyakarta by Daphna International  3.5 of 5 bubbles
# 26                      Grand Serela Hotel Yogyakarta    4 of 5 bubbles
# 27                            Indoluxe Rent Apartment    3 of 5 bubbles
# 28                        Hotel Citradream Yogyakarta    4 of 5 bubbles
# 29                           Ayaartta Hotel Malioboro    4 of 5 bubbles
#
#     No_of_reviews            Harga
# 0     458 reviews  231,405 134,561
# 1   1,488 reviews          785,124
# 2     920 reviews          384,366
# 3   1,456 reviews  390,266 302,290
# 4     538 reviews  356,095 312,188
# 5   1,159 reviews  427,810 304,876
# 6     280 reviews  330,579 231,133
# 7     626 reviews          329,752
# 8      87 reviews          371,074
# 9      29 reviews  203,671 151,212
# 10    180 reviews  595,041 227,273
# 11    423 reviews  247,108 190,472
# 12    845 reviews  196,281 186,090
# 13    299 reviews          148,760
# 14     65 reviews           97,587
# 15     30 reviews          115,206
# 16    101 reviews          179,273
# 17     11 reviews          135,733
# 18     92 reviews  256,198 168,066
# 19    114 reviews  190,082 154,554
# 20    902 reviews
# 21    209 reviews
# 22    664 reviews
# 23  1,290 reviews
# 24     64 reviews
# 25      6 reviews
# 26    100 reviews
# 27      4 reviews
# 28    136 reviews
# 29     79 reviews
